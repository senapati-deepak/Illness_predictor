# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("../data/CAB_23_MP.csv", low_memory=False)

# %%
data.shape
# Out:
# (261137, 54)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261137 entries, 0 to 261136
# Data columns (total 54 columns):
# state_code                          261137 non-null int64
# district_code                       261137 non-null int64
# rural_urban                         261137 non-null int64
# stratum                             261137 non-null int64
# psu_id                              261137 non-null int64
# ahs_house_unit                      261137 non-null int64
# house_hold_no                       261137 non-null int64
# date_survey                         261137 non-null object
# test_salt_iodine                    261137 non-null int64
# record_code_iodine                  261137 non-null int64
# record_code_iodine_reason           3151 non-null object
# sl_no                               261137 non-null int64
# sex                                 261137 non-null int64
# usual_residance                     261137 non-null int64
# usual_residance_reason              6413 non-null object
# identification_code                 261136 non-null float64
# age_code                            261137 non-null object
# age                                 261137 non-null int64
# date_of_birth                       261137 non-null int64
# month_of_birth                      261137 non-null int64
# year_of_birth                       261137 non-null int64
# weight_measured                     261137 non-null int64
# weight_in_kg                        261137 non-null float64
# length_height_measured              261137 non-null int64
# length_height_code                  261137 non-null object
# length_height_cm                    261137 non-null float64
# haemoglobin_test                    261137 non-null int64
# haemoglobin                         261137 non-null int64
# haemoglobin_level                   261137 non-null float64
# bp_systolic                         261137 non-null int64
# bp_systolic_2_reading               261137 non-null int64
# bp_diastolic                        261137 non-null int64
# bp_diastolic_2reading               261137 non-null int64
# pulse_rate                          261137 non-null int64
# pulse_rate_2_reading                261137 non-null int64
# diabetes_test                       261137 non-null int64
# fasting_blood_glucose               261137 non-null int64
# fasting_blood_glucose_mg_dl         261137 non-null float64
# marital_status                      261137 non-null int64
# gauna_perfor_not_perfor             261137 non-null int64
# duration_pregnanacy                 261137 non-null int64
# first_breast_feeding                261137 non-null int64
# is_cur_breast_feeding               261137 non-null int64
# day_or_month_for_breast_feeding_    261137 non-null object
# day_or_month_for_breast_feeding     261137 non-null int64
# water_month                         261137 non-null int64
# ani_milk_month                      261137 non-null int64
# semisolid_month_or_day              261137 non-null int64
# solid_month                         261137 non-null int64
# vegetables_month_or_day             261137 non-null int64
# illness_type                        261137 non-null int64
# illness_duration                    261137 non-null int64
# treatment_type                      261137 non-null int64
# v54                                 0 non-null float64
# dtypes: float64(6), int64(42), object(6)
# memory usage: 107.6+ MB

# %%
data.columns.values
# Out:
# array(['state_code', 'district_code', 'rural_urban', 'stratum', 'psu_id',
#        'ahs_house_unit', 'house_hold_no', 'date_survey',
#        'test_salt_iodine', 'record_code_iodine',
#        'record_code_iodine_reason', 'sl_no', 'sex', 'usual_residance',
#        'usual_residance_reason', 'identification_code', 'age_code', 'age',
#        'date_of_birth', 'month_of_birth', 'year_of_birth',
#        'weight_measured', 'weight_in_kg', 'length_height_measured',
#        'length_height_code', 'length_height_cm', 'haemoglobin_test',
#        'haemoglobin', 'haemoglobin_level', 'bp_systolic',
#        'bp_systolic_2_reading', 'bp_diastolic', 'bp_diastolic_2reading',
#        'pulse_rate', 'pulse_rate_2_reading', 'diabetes_test',
#        'fasting_blood_glucose', 'fasting_blood_glucose_mg_dl',
#        'marital_status', 'gauna_perfor_not_perfor', 'duration_pregnanacy',
#        'first_breast_feeding', 'is_cur_breast_feeding',
#        'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'illness_duration', 'treatment_type', 'v54'], dtype=object)

# %%
data = data.drop([ 'psu_id','ahs_house_unit','house_hold_no', 'date_survey',
                  'test_salt_iodine', 'record_code_iodine_reason', 'sl_no', 'usual_residance_reason',
                  'identification_code', 'date_of_birth', 'year_of_birth', 'weight_measured',
                  'length_height_measured', 'length_height_code', 'haemoglobin_test', 'haemoglobin', 'bp_systolic',
                  'bp_systolic_2_reading', 'bp_diastolic', 'bp_diastolic_2reading', 'pulse_rate',
                  'pulse_rate_2_reading', 'diabetes_test', 'fasting_blood_glucose', 'fasting_blood_glucose_mg_dl',
                  'marital_status', 'gauna_perfor_not_perfor', 'duration_pregnanacy', 'illness_duration', 'v54'],
                axis = 1)

# %%
data.shape
# Out:
# (261137, 24)

# %%
data.columns.values
# Out:
# array(['state_code', 'district_code', 'rural_urban', 'stratum',
#        'record_code_iodine', 'sex', 'usual_residance', 'age_code', 'age',
#        'month_of_birth', 'weight_in_kg', 'length_height_cm',
#        'haemoglobin_level', 'first_breast_feeding',
#        'is_cur_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'treatment_type'], dtype=object)

# %%
data = data.drop(data[(data['age_code'] == 'Y') & (data['age'] > 5) | (data['illness_type'] == -1)].index)

# %%
data.shape
# Out:
# (14661, 24)

# %%
data['illness_type'].value_counts()
# Out:
# 0    11159
# 2     1841
# 1     1197
# 3      403
# 4       61
# Name: illness_type, dtype: int64

# %%
data['illness_type'].value_counts() / 146.61
# Out:
# 0    76.113498
# 2    12.557124
# 1     8.164518
# 3     2.748789
# 4     0.416070
# Name: illness_type, dtype: float64

# %%
data['age_code'].value_counts()
# Out:
# Y    12337
# M     2235
# D       79
# y        9
# m        1
# Name: age_code, dtype: int64

# %%
data['age_code'][data['age_code'] == 'm'] = 'M'
data['age_code'][data['age_code'] == 'y'] = 'Y'
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['age_code'].value_counts()
# Out:
# Y    12346
# M     2236
# D       79
# Name: age_code, dtype: int64

# %%
print(data['rural_urban'].value_counts())
print(data['stratum'].value_counts())
print(data['record_code_iodine'].value_counts())
print(data['sex'].value_counts())
print(data['usual_residance'].value_counts())
print(data['age_code'].value_counts())
print(data['month_of_birth'].value_counts())
# Out:
# 1    11018
# 2     3643
# Name: rural_urban, dtype: int64
# 1    6082
# 2    4936
# 0    3643
# Name: stratum, dtype: int64
# 3    13720
# 2      696
# 1      245
# Name: record_code_iodine, dtype: int64
# 1    7747
# 2    6914
# Name: sex, dtype: int64
# 1    14658
# 2        3
# Name: usual_residance, dtype: int64
# Y    12346
# M     2236
# D       79
# Name: age_code, dtype: int64
# 6     3510
# 1     2829
# 8     1042
# 9      883
# 2      867
# 7      845
# 12     827
# 5      818
# 4      781
# 3      776
# 11     750
# 10     733
# Name: month_of_birth, dtype: int64

# %%
data['illness_type'].groupby(data['month_of_birth']).mean()
# Out:
# month_of_birth
# 1     0.273595
# 2     0.464821
# 3     0.490979
# 4     0.532650
# 5     0.490220
# 6     0.428490
# 7     0.514793
# 8     0.438580
# 9     0.502831
# 10    0.506139
# 11    0.504000
# 12    0.444982
# Name: illness_type, dtype: float64

# %%
data.shape
# Out:
# (14661, 24)

# %%
data['age_code'].value_counts()
# Out:
# Y    12346
# M     2236
# D       79
# Name: age_code, dtype: int64

# %%
data['record_code_iodine'].value_counts()
# Out:
# 3    13720
# 2      696
# 1      245
# Name: record_code_iodine, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# 1    7747
# 2    6914
# Name: sex, dtype: int64

# %%
data['day_or_month_for_breast_feeding_'].value_counts()
# Out:
# M     7612
# -1    6945
# D      103
# m        1
# Name: day_or_month_for_breast_feeding_, dtype: int64

# %%
data['day_or_month_for_breast_feeding_'][data['day_or_month_for_breast_feeding_'] == 'm'] = 'M'
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['day_or_month_for_breast_feeding_'].value_counts()
# Out:
# M     7613
# -1    6945
# D      103
# Name: day_or_month_for_breast_feeding_, dtype: int64

# %%
#droping birth month
data = data.drop('month_of_birth', axis=1)
data.shape
# Out:
# (14661, 23)

# %%
data.columns.unique()
# Out:
# Index(['state_code', 'district_code', 'rural_urban', 'stratum',
#        'record_code_iodine', 'sex', 'usual_residance', 'age_code', 'age',
#        'weight_in_kg', 'length_height_cm', 'haemoglobin_level',
#        'first_breast_feeding', 'is_cur_breast_feeding',
#        'day_or_month_for_breast_feeding_', 'day_or_month_for_breast_feeding',
#        'water_month', 'ani_milk_month', 'semisolid_month_or_day',
#        'solid_month', 'vegetables_month_or_day', 'illness_type',
#        'treatment_type'],
#       dtype='object')

# %%
data = data.drop('rural_urban',axis=1)

# %%
data.columns.values
# Out:
# array(['state_code', 'district_code', 'stratum', 'record_code_iodine',
#        'sex', 'usual_residance', 'age_code', 'age', 'weight_in_kg',
#        'length_height_cm', 'haemoglobin_level', 'first_breast_feeding',
#        'is_cur_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'treatment_type'], dtype=object)

# %%
data = data.drop(['stratum', 'usual_residance'],axis=1)

# %%
data.columns.values
# Out:
# array(['state_code', 'district_code', 'record_code_iodine', 'sex',
#        'age_code', 'age', 'weight_in_kg', 'length_height_cm',
#        'haemoglobin_level', 'first_breast_feeding',
#        'is_cur_breast_feeding', 'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'treatment_type'], dtype=object)

# %%
data['weight_in_kg'][data[data['weight_in_kg'] == -1].index].value_counts()
# Out:
# -1.0    1516
# Name: weight_in_kg, dtype: int64

# %%
print(data['record_code_iodine'][data[data['record_code_iodine'] == -1].index].value_counts())
print(data['sex'][data[data['sex'] == -1].index].value_counts())
print(data['age_code'][data[data['age_code'] == -1].index].value_counts())
print(data['age'][data[data['age'] == -1].index].value_counts())
print(data['weight_in_kg'][data[data['weight_in_kg'] == -1].index].value_counts())
print(data['length_height_cm'][data[data['length_height_cm'] == -1].index].value_counts())
print(data['haemoglobin_level'][data[data['haemoglobin_level'] == -1].index].value_counts())
print(data['first_breast_feeding'][data[data['first_breast_feeding'] == -1].index].value_counts())
print(data['is_cur_breast_feeding'][data[data['is_cur_breast_feeding'] == -1].index].value_counts())
print(data['day_or_month_for_breast_feeding_'][data[data['day_or_month_for_breast_feeding_'] == -1].index].value_counts())
print(data['day_or_month_for_breast_feeding'][data[data['day_or_month_for_breast_feeding'] == -1].index].value_counts())
print(data['water_month'][data[data['water_month'] == -1].index].value_counts())
print(data['ani_milk_month'][data[data['ani_milk_month'] == -1].index].value_counts())
print(data['semisolid_month_or_day'][data[data['semisolid_month_or_day'] == -1].index].value_counts())
print(data['solid_month'][data[data['solid_month'] == -1].index].value_counts())
print(data['vegetables_month_or_day'][data[data['vegetables_month_or_day'] == -1].index].value_counts())
# Out:
# Series([], Name: record_code_iodine, dtype: int64)
# Series([], Name: sex, dtype: int64)
# Series([], Name: age_code, dtype: int64)
# Series([], Name: age, dtype: int64)
# -1.0    1516
# Name: weight_in_kg, dtype: int64
# -1.0    1527
# Name: length_height_cm, dtype: int64
# -1.0    7354
# Name: haemoglobin_level, dtype: int64
# -1    6934
# Name: first_breast_feeding, dtype: int64
# -1    6941
# Name: is_cur_breast_feeding, dtype: int64
# Series([], Name: day_or_month_for_breast_feeding_, dtype: int64)
# -1    6951
# Name: day_or_month_for_breast_feeding, dtype: int64
# -1    6944
# Name: water_month, dtype: int64
# -1    6949
# Name: ani_milk_month, dtype: int64
# -1    6948
# Name: semisolid_month_or_day, dtype: int64
# -1    6961
# Name: solid_month, dtype: int64
# -1    6962
# Name: vegetables_month_or_day, dtype: int64

# %%
data.shape
# Out:
# (14661, 20)

# %%
data['water_month'][data[data['water_month'] == -1].index].value_counts()
# Out:
# -1    6944
# Name: water_month, dtype: int64

# %%
data['semisolid_month_or_day'][data[data['semisolid_month_or_day'] == -1].index].value_counts()
# Out:
# -1    6948
# Name: semisolid_month_or_day, dtype: int64

# %%
data['is_cur_breast_feeding'][data[(data['is_cur_breast_feeding'] == -1)].index].value_counts()
# Out:
# -1    6941
# Name: is_cur_breast_feeding, dtype: int64

# %%
data['is_cur_breast_feeding'][data[(data['is_cur_breast_feeding'] == -1) & (data['age']>2) & (data['age_code'] == 'Y')].index].value_counts()
# Out:
# -1    6757
# Name: is_cur_breast_feeding, dtype: int64

# %%
# data['is_cur_breast_feeding'][data[(data['age_code'] == 'Y') & (data['age'] > 2) & (data['is_cur_breast_feeding'] == -1)].index] = 2
data.loc[((data['age']>2) & (data['age_code'] == 'Y') & (data['is_cur_breast_feeding'] == -1)),'is_cur_breast_feeding'] = 2

# %%
data['is_cur_breast_feeding'][data[data['is_cur_breast_feeding'] == -1].index].value_counts()
# Out:
# -1    184
# Name: is_cur_breast_feeding, dtype: int64

# %%
data['is_cur_breast_feeding'] = data['is_cur_breast_feeding'].replace(-1, 1)

# %%
data['age'][data[data['is_cur_breast_feeding'] == -1].index]
# Out:
# Series([], Name: age, dtype: int64)

# %%
data['weight_in_kg'][data[(data['weight_in_kg'] == -1)].index].value_counts()
# Out:
# -1.0    1516
# Name: weight_in_kg, dtype: int64

# %%
data['age_code'][data[(data['weight_in_kg'] == -1)].index].value_counts()
# Out:
# Y    1385
# D      79
# M      52
# Name: age_code, dtype: int64

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['weight_in_kg'][data[(data['age_code'] == y) & (data['age'] == i) & (data['weight_in_kg'] != -1)].index].mean()
        data.loc[((data['age_code'] == y) & (data['age'] == i) & (data['weight_in_kg'] == -1)), 'weight_in_kg'] = x

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['weight_in_kg'][data[(data['age_code'] == y) & (data['age'] == i) & (data['weight_in_kg'] != -1)].index].mean()
        data['weight_in_kg'] = data['weight_in_kg'].fillna(x)

# %%
data['weight_in_kg'][data[(data['weight_in_kg'] == -1)].index].value_counts()
# Out:
# Series([], Name: weight_in_kg, dtype: int64)

# %%
data['length_height_cm'][data[(data['length_height_cm'] == -1)].index].value_counts()
# Out:
# -1.0    1527
# Name: length_height_cm, dtype: int64

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['length_height_cm'][data[(data['age_code'] == y) & (data['age'] == i) & (data['length_height_cm'] != -1)].index].mean()
        data.loc[((data['age_code'] == y) & (data['age'] == i) & (data['length_height_cm'] == -1)), 'length_height_cm'] = x

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['length_height_cm'][data[(data['age_code'] == y) & (data['age'] == i) & (data['length_height_cm'] != -1)].index].mean()
        data['length_height_cm'] = data['length_height_cm'].fillna(x)

# %%
data['length_height_cm'][data[(data['length_height_cm'] == -1)].index].value_counts()
# Out:
# Series([], Name: length_height_cm, dtype: int64)

# %%
data['haemoglobin_level'][data[(data['haemoglobin_level'] == -1)].index].value_counts()
# Out:
# -1.0    7354
# Name: haemoglobin_level, dtype: int64

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['haemoglobin_level'][data[(data['age_code'] == y) & (data['age'] == i) & (data['haemoglobin_level'] != -1)].index].mean()
        data.loc[((data['age_code'] == y) & (data['age'] == i) & (data['haemoglobin_level'] == -1)), 'haemoglobin_level'] = x

# %%
for y in data['age_code'].unique():
    for i in data['age'][data[data['age_code'] == y].index].unique():
        x = data['haemoglobin_level'][data[(data['age_code'] == y) & (data['age'] == i) & (data['haemoglobin_level'] != -1)].index].mean()
        data['haemoglobin_level'] = data['haemoglobin_level'].fillna(x)

# %%
data['haemoglobin_level'][data[(data['haemoglobin_level'] == -1)].index].value_counts()
# Out:
# Series([], Name: haemoglobin_level, dtype: int64)

# %%
data['first_breast_feeding'][data[(data['first_breast_feeding'] == -1)].index].value_counts()
# Out:
# -1    6934
# Name: first_breast_feeding, dtype: int64

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['district_code'][data[data['district_code']==i].index].value_counts()
    print(x[i])
    print((data['first_breast_feeding'][data[data['district_code']==i].index].value_counts().sort_index())*100/x[i])
    print("----------------------------------------------------")
# Out:
# 1
# 546
# -1    44.688645
#  1    47.435897
#  2     7.692308
#  4     0.183150
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 2
# 221
# -1    55.656109
#  1    34.389140
#  2     9.954751
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
#
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 38
# 234
# -1    14.529915
#  1    76.923077
#  2     8.547009
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 39
# 251
# -1    32.270916
#  1    52.988048
#  2     9.960159
#  3     3.984064
#  4     0.796813
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 40
# 210
# -1    28.571429
#  1    43.809524
#  2    26.190476
#  3     1.428571
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 41
# 414
# -1    38.164251
#  1    18.357488
#  2    39.130435
#  3     3.140097
#  4     1.207729
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 42
# 361
# -1    42.382271
#  1    33.518006
#  2    24.099723
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 43
# 285
# -1    30.526316
#  1    39.649123
#  2    27.368421
#  3     2.456140
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 44
# 273
# -1    36.630037
#  1    25.274725
#  2    34.432234
#  3     1.831502
#  4     1.831502
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------
# 45
# 482
# -1    51.867220
#  1    11.825726
#  2    34.854772
#  3     1.452282
# Name: first_breast_feeding, dtype: float64
# ----------------------------------------------------

# %%
for i in data['district_code'].unique():
    x = data['first_breast_feeding'][data[(data['district_code'] == i) & (data['first_breast_feeding'] != -1)].index].value_counts()
    y = x[x == x.max()].index.item()
    data.loc[((data['district_code'] == i) & (data['first_breast_feeding'] == -1)), 'first_breast_feeding'] = y

# %%
for i in data['district_code'].unique():
    x = data['first_breast_feeding'][data[(data['district_code'] == i) & (data['first_breast_feeding'] != -1)].index].value_counts()
    y = x[x == x.max()].index.item()
    data['first_breast_feeding'] = data['first_breast_feeding'].fillna(y)

# %%
data['first_breast_feeding'][data[(data['first_breast_feeding'] == -1)].index].value_counts()
# Out:
# Series([], Name: first_breast_feeding, dtype: int64)

# %%
data['day_or_month_for_breast_feeding'][data[(data['day_or_month_for_breast_feeding'] == -1)].index].value_counts()
# Out:
# -1    6951
# Name: day_or_month_for_breast_feeding, dtype: int64

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['district_code'][data[data['district_code']==i].index].value_counts()
    print(x[i])
    print((data['day_or_month_for_breast_feeding'][data[data['district_code']==i].index].value_counts().sort_index())*100/x[i])
    print("----------------------------------------------------")
# Out:
# 1
# 546
# -1     44.688645
#  0      2.014652
#  1      1.098901
#  2      1.098901
#  3      2.564103
#  4      4.761905
#  5     15.750916
#  6     25.824176
#  7      1.465201
#  9      0.183150
#  10     0.183150
#  15     0.366300
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 2
# 221
# -1     55.656109
#  0      3.167421
#  1      0.452489
#  2      0.904977
#  3      1.809955
#  4      3.167421
#  5      4.072398
#  6     12.217195
#  7      4.524887
#  8      0.452489
#  9      1.357466
#  10     0.452489
#  11     0.452489
#  12     1.357466
#  13     2.714932
#  14     0.452489
#  16     0.904977
#  18     0.904977
#  20     0.904977
#  21     1.357466
#  23     0.452489
#  24     0.452489
#  32     0.452489
#  33     0.452489
#  34     0.452489
#  36     0.452489
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 3
# 318
# -1     58.176101
#  0      0.943396
#  1      1.886792
#  2      1.886792
#  3      2.201258
#  4      1.886792
#  5      1.257862
#  6     21.069182
#  7      0.943396
#  8      1.572327
#  9      0.628931
#  10     2.515723
#  11     0.628931
#  12     1.572327
#  13     0.314465
#  14     0.314465
#  16     0.314465
#  20     0.628931
#  22     0.628931
#  23     0.314465
#  28     0.314465
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 4
# 356
# -1     53.089888
#  0      1.123596
#  1      0.280899
#  2      1.123596
#  3      0.842697
#  4      1.404494
#  5      3.370787
#  6     24.157303
#  7      2.247191
#  8      1.966292
#  9      1.404494
#  10     0.842697
#  11     0.842697
#  12     1.685393
#  13     1.966292
#  14     1.123596
#  15     1.404494
#  16     0.280899
#  19     0.280899
#  20     0.280899
#  24     0.280899
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
#
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 43
# 285
# -1    30.526316
#  1     1.403509
#  2     1.754386
#  3     7.017544
#  4    11.578947
#  5    33.333333
#  6    14.385965
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 44
# 273
# -1    36.630037
#  0     0.366300
#  1     1.465201
#  2     3.296703
#  3     2.564103
#  4     6.227106
#  5    36.996337
#  6    12.454212
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------
# 45
# 482
# -1     51.867220
#  1      0.829876
#  2      0.622407
#  3      9.543568
#  4     13.278008
#  5     14.315353
#  6      9.336100
#  12     0.207469
# Name: day_or_month_for_breast_feeding, dtype: float64
# ----------------------------------------------------

# %%
data.loc[(data['day_or_month_for_breast_feeding'] == -1), 'day_or_month_for_breast_feeding'] = 6

# %%
data['day_or_month_for_breast_feeding'][data[(data['day_or_month_for_breast_feeding'] == -1)].index].value_counts()
# Out:
# Series([], Name: day_or_month_for_breast_feeding, dtype: int64)

# %%
print(data['water_month'][data[data['water_month'] == -1].index].value_counts())
print(data['ani_milk_month'][data[data['ani_milk_month'] == -1].index].value_counts())
print(data['semisolid_month_or_day'][data[data['semisolid_month_or_day'] == -1].index].value_counts())
print(data['solid_month'][data[data['solid_month'] == -1].index].value_counts())
print(data['vegetables_month_or_day'][data[data['vegetables_month_or_day'] == -1].index].value_counts())
# Out:
# -1    6944
# Name: water_month, dtype: int64
# -1    6949
# Name: ani_milk_month, dtype: int64
# -1    6948
# Name: semisolid_month_or_day, dtype: int64
# -1    6961
# Name: solid_month, dtype: int64
# -1    6962
# Name: vegetables_month_or_day, dtype: int64

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['water_month'][data[(data['district_code'] == i) & (data['water_month'] != -1)].index].value_counts()
    print(x)
    y = x[x == x.max()].index.tolist()
    print(y[0])
    data.loc[((data['district_code'] == i) & (data['water_month'] == -1)), 'water_month'] = y[0]
# Out:
# 1
# 5     99
# 6     91
# 7     62
# 0     31
# 4      9
# 3      6
# 9      2
# 10     1
# 8      1
# Name: water_month, dtype: int64
# 5
# 2
# 5     36
# 0     27
# 7     13
# 6     12
# 9      5
# 12     1
# 10     1
# 8      1
# 4      1
# 1      1
# Name: water_month, dtype: int64
# 5
# 3
# 5     58
# 0     24
# 7     10
# 1     10
# 11     7
# 8      5
# 9      4
# 6      4
# 13     3
# 4      3
# 15     1
# 14     1
# 12     1
# 10     1
# 2      1
# Name: water_month, dtype: int64
# 5
# 4
# 6     65
# 7     33
# 5     28
# 0     18
# 8      9
# 9      4
# 4      4
# 10     3
# 1      2
# 16     1
# 2      1
# Name: water_month, dtype: int64
# 6
# 5
# 0    32
# 5    26
# 7    17
# 6    13
# 1     4
# 8     2
# 9     1
# Name: water_month, dtype: int64
# 0
# 6
# 6     72
# 5     69
# 0     21
# 7     12
# 8      9
# 4      8
# 3      5
# 10     4
# 2      3
# 1      3
# 9      2
# 12     1
# 11     1
# Name: water_month, dtype: int64
# 6
# 7
# 5     64
# 0     34
# 7     28
# 9     17
# 8      6
# 6      6
# 3      6
# 2      3
# 1      3
# 4      2
# 10     1
# Name: water_month, dtype: int64
# 5
# 8
# 6    126
# 7     46
# 8     17
# 0     16
# 5      7
# 3      7
# 4      6
# 9      1
# Name: water_month, dtype: int64
# 6
# 9
# 7    92
# 6    90
# 0    28
# 5    15
# 8     9
# 4     3
# 3     2
# 9     1
# Name: water_month, dtype: int64
# 7
# 10
# 6     88
# 7     38
# 0     30
# 5      6
# 8      5
# 3      5
# 4      3
# 10     1
# Name: water_month, dtype: int64
# 6
# 11
# 6    118
# 7     68
# 0     37
# 5     25
# 8      7
# 4      7
# 3      4
# 9      3
# Name: water_month, dtype: int64
# 6
# 12
# 6    167
# 7     35
# 0     22
# 5     20
# 4      9
# 3      9
# 8      4
# 9      2
# 1      1
# Name: water_month, dtype: int64
# 6
# 13
# 0    54
# 7    48
# 6    34
# 8    22
# 9     3
# 5     3
# Name: water_month, dtype: int64
# 0
# 14
# 5    44
# 0    36
# 6    33
# 7    16
# 4    12
# 3     1
# Name: water_month, dtype: int64
# 5
# 15
# 6    135
# 0     35
# 7     19
# 5      6
# 8      5
# 9      1
# 4      1
# Name: water_month, dtype: int64
# 6
# 16
# 6    116
# 7     59
# 0     43
# 5     11
# 8      2
# Name: water_month, dtype: int64
# 6
# 17
# 7    78
# 6    63
# 0    38
# 8     8
# 5     3
# 4     3
# 3     3
# 9     1
# Name: water_month, dtype: int64
# 7
# 18
# 5    21
# 0     7
# 6     6
# 7     5
# 9     1
# 8     1
# 4     1
# 3     1
# 2     1
# Name: water_month, dtype: int64
# 5
# 19
# 5    30
# 6    15
# 7    12
# 0     8
# 9     3
# 4     3
# 1     3
# 2     2
# Name: water_month, dtype: int64
# 5
# 20
# 5     37
# 0      9
# 14     5
# 13     5
# 6      4
# 4      4
# 15     2
# 11     2
# 10     2
# 7      2
# 12     1
# 3      1
# 2      1
# 1      1
# Name: water_month, dtype: int64
# 5
# 21
# 5     78
# 6     25
# 0     15
# 7     13
# 4     10
# 11     6
# 13     5
# 12     5
# 14     3
# 9      3
# 10     2
# 8      2
# 3      1
# 2      1
# 1      1
# Name: water_month, dtype: int64
# 5
# 22
# 7     39
# 5     37
# 6     12
# 0     10
# 9      8
# 10     2
# 8      2
# 4      1
# 2      1
# Name: water_month, dtype: int64
# 7
# 23
# 5     110
# 10     17
# 0      16
# 7      15
# 6      15
# 8      13
# 12     11
# 9      11
# 11      6
# 3       3
# 13      2
# 4       2
# 15      1
# 14      1
# 2       1
# Name: water_month, dtype: int64
# 5
# 24
# 7    35
# 5    33
# 6    32
# 0     9
# 8     2
# 9     1
# Name: water_month, dtype: int64
# 7
# 25
# 5     40
# 6     22
# 0      3
# 13     2
# 16     1
# 15     1
# 14     1
# 12     1
# 8      1
# 4      1
# Name: water_month, dtype: int64
# 5
# 26
# 7     77
# 5     51
# 6     28
# 0     26
# 8     19
# 9     12
# 11    10
# 10     9
# 4      9
# 12     7
# 1      5
# 13     2
# 3      2
# 2      2
# 14     1
# Name: water_month, dtype: int64
# 7
# 27
# 5    38
# 0    23
# 7    17
# 6     9
# 1     9
# 8     3
# 9     2
# 4     1
# Name: water_month, dtype: int64
# 5
# 28
# 5     82
# 0     10
# 6      8
# 7      4
# 13     3
# 9      3
# 1      3
# 14     2
# 12     2
# 3      2
# 16     1
# 15     1
# 11     1
# 10     1
# Name: water_month, dtype: int64
# 5
# 29
# 5     74
# 6     50
# 0     22
# 7     16
# 1     13
# 8     11
# 3     11
# 12     4
# 10     3
# 9      3
# 4      3
# 2      2
# Name: water_month, dtype: int64
# 5
# 30
# 5    45
# 0    18
# 6     7
# 7     3
# 8     1
# 4     1
# Name: water_month, dtype: int64
# 5
# 31
# 6    90
# 0    37
# 7    20
# 5    13
# 8     9
# 4     6
# 3     4
# Name: water_month, dtype: int64
# 6
# 32
# 5     57
# 6     27
# 7     26
# 0     26
# 1      7
# 8      4
# 4      4
# 10     3
# 9      3
# 12     2
# 20     1
# 11     1
# 2      1
# Name: water_month, dtype: int64
# 5
# 33
# 5    52
# 7    11
# 8     6
# 9     5
# 6     4
# 0     4
# 4     1
# 1     1
# Name: water_month, dtype: int64
# 5
# 34
# 6    71
# 7    44
# 0    37
# 5     5
# 8     4
# 9     2
# Name: water_month, dtype: int64
# 6
# 35
# 6    68
# 0    44
# 5    29
# 7    27
# 4    12
# 3     9
# 9     6
# 8     2
# Name: water_month, dtype: int64
# 6
# 36
# 6    49
# 7    34
# 0    22
# 5    18
# 4    13
# 8    10
# 3     8
# 9     1
# Name: water_month, dtype: int64
# 6
# 37
# 6    135
# 0     48
# 7     32
# 5      9
# 8      7
# 4      4
# 3      4
# Name: water_month, dtype: int64
# 6
# 38
# 6    112
# 0     41
# 5     16
# 7     15
# 4      9
# 8      4
# 3      3
# Name: water_month, dtype: int64
# 6
# 39
# 6    72
# 7    37
# 0    31
# 5    19
# 4     7
# 8     3
# 3     1
# Name: water_month, dtype: int64
# 6
# 40
# 6    42
# 0    41
# 7    34
# 5    14
# 8    10
# 4     7
# 3     2
# Name: water_month, dtype: int64
# 6
# 41
# 6    160
# 0     44
# 7     18
# 5     15
# 4     11
# 3      7
# 8      1
# Name: water_month, dtype: int64
# 6
# 42
# 6    99
# 5    37
# 7    33
# 0    33
# 4     3
# 8     2
# 3     1
# Name: water_month, dtype: int64
# 6
# 43
# 6    90
# 7    38
# 5    27
# 0    25
# 4    14
# 8     3
# 3     1
# Name: water_month, dtype: int64
# 6
# 44
# 6    100
# 0     28
# 7     26
# 5     12
# 8      4
# 9      1
# 4      1
# 3      1
# Name: water_month, dtype: int64
# 6
# 45
# 6    61
# 5    48
# 4    42
# 0    41
# 7    40
# Name: water_month, dtype: int64
# 6

# %%
for i in data['district_code'].unique():
    x = data['water_month'][data[(data['district_code'] == i) & (data['water_month'] != -1)].index].value_counts()
    y = x[x == x.max()].index.tolist()
    data['water_month'] = data['water_month'].fillna(y[0])

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['ani_milk_month'][data[(data['district_code'] == i) & (data['ani_milk_month'] != -1)].index].value_counts()
    print(x)
    y = x[x == x.max()].index.tolist()
    print(y[0])
    data.loc[((data['district_code'] == i) & (data['ani_milk_month'] == -1)), 'ani_milk_month'] = y[0]
# Out:
# 1
# 6     116
# 7      54
# 0      41
# 8      33
# 9      25
# 5      16
# 4      10
# 10      4
# 12      2
# 3       1
# Name: ani_milk_month, dtype: int64
# 6
# 2
# 6     32
# 0     30
# 9     16
# 7     10
# 12     4
# 14     1
# 11     1
# 10     1
# 5      1
# 4      1
# 1      1
# Name: ani_milk_month, dtype: int64
# 6
# 3
# 6     59
# 0     26
# 1     10
# 12     7
# 10     6
# 7      6
# 8      5
# 9      4
# 15     2
# 14     2
# 11     2
# 4      2
# 18     1
# 2      1
# Name: ani_milk_month, dtype: int64
# 6
# 4
# 9     37
# 7     35
# 0     32
# 6     28
# 8     24
# 12     3
# 14     2
# 3      2
# 1      2
# 11     1
# 10     1
# 5      1
# Name: ani_milk_month, dtype: int64
# 9
# 5
# 0     38
# 6     24
# 9     16
# 8      6
# 12     3
# 10     3
# 1      3
# 7      1
# 3      1
# Name: ani_milk_month, dtype: int64
# 0
# 6
# 6     66
# 8     38
# 7     31
# 0     27
# 9     16
# 10    11
# 12     9
# 4      3
# 15     2
# 5      2
# 1      2
# 27     1
# 17     1
# 13     1
# Name: ani_milk_month, dtype: int64
# 6
# 7
# 6     59
# 0     49
# 9     17
# 8     13
# 12     7
# 7      6
# 10     4
# 4      4
# 3      4
# 11     3
# 2      2
# 16     1
# 1      1
# Name: ani_milk_month, dtype: int64
# 6
# 8
# 6     96
# 8     39
# 7     38
# 0     24
# 9     11
# 4      7
# 5      6
# 10     4
# 12     1
# Name: ani_milk_month, dtype: int64
# 6
# 9
# 7    74
# 8    59
# 6    56
# 0    31
# 5    11
# 9     7
# 4     2
# Name: ani_milk_month, dtype: int64
# 7
# 10
# 6     63
# 7     35
# 0     33
# 8     29
# 9      6
# 4      5
# 5      4
# 13     1
# Name: ani_milk_month, dtype: int64
# 6
# 11
# 6     83
# 7     65
# 8     52
# 0     52
# 5      6
# 4      6
# 9      4
# 10     1
# Name: ani_milk_month, dtype: int64
# 6
# 12
# 6    101
# 7     72
# 0     41
# 8     33
# 5     10
# 4      8
# 9      4
# Name: ani_milk_month, dtype: int64
# 6
# 13
# 0    60
# 8    44
# 7    37
# 6    18
# 9     3
# 5     2
# Name: ani_milk_month, dtype: int64
# 0
# 14
# 7     39
# 0     39
# 8     17
# 6     16
# 5     16
# 9      8
# 10     6
# 12     1
# Name: ani_milk_month, dtype: int64
# 7
# 15
# 6     66
# 7     49
# 0     37
# 8     29
# 5     10
# 10     5
# 9      5
# 11     1
# Name: ani_milk_month, dtype: int64
# 6
# 16
# 7     124
# 0      44
# 6      43
# 8       9
# 5       3
# 10      2
# 3       2
# 9       1
# 2       1
# Name: ani_milk_month, dtype: int64
# 7
# 17
# 7     71
# 8     47
# 0     45
# 6     17
# 9     12
# 10     5
# Name: ani_milk_month, dtype: int64
# 7
# 18
# 6     16
# 0     12
# 9      6
# 7      6
# 8      3
# 12     1
# Name: ani_milk_month, dtype: int64
# 6
# 19
# 6     30
# 7     18
# 0     11
# 9      4
# 12     3
# 8      3
# 5      2
# 4      2
# 1      2
# 2      1
# Name: ani_milk_month, dtype: int64
# 6
# 20
# 6     35
# 0     15
# 14     6
# 7      5
# 15     3
# 12     3
# 16     2
# 11     2
# 9      2
# 13     1
# 8      1
# Name: ani_milk_month, dtype: int64
# 6
# 21
# 6     79
# 0     27
# 7     20
# 8     12
# 13     6
# 12     5
# 15     4
# 14     4
# 9      4
# 10     3
# 11     2
# 5      2
# 4      1
# 3      1
# Name: ani_milk_month, dtype: int64
# 6
# 22
# 6     35
# 9     24
# 0     21
# 8     15
# 12     7
# 10     4
# 7      4
# 16     1
# 11     1
# Name: ani_milk_month, dtype: int64
# 6
# 23
# 6     113
# 0      19
# 7      17
# 11     14
# 12     12
# 10     12
# 8      12
# 9      10
# 13      5
# 14      3
# 15      2
# 4       2
# 5       1
# 2       1
# Name: ani_milk_month, dtype: int64
# 6
# 24
# 8     29
# 6     26
# 9     22
# 7     21
# 0     10
# 11     2
# 10     1
# 5      1
# Name: ani_milk_month, dtype: int64
# 8
# 25
# 6     40
# 8     16
# 7      7
# 0      4
# 15     2
# 14     2
# 12     1
# 10     1
# Name: ani_milk_month, dtype: int64
# 6
# 26
# 6     61
# 7     47
# 8     40
# 0     39
# 9     17
# 10    14
# 12    11
# 11     9
# 4      7
# 13     4
# 5      3
# 1      3
# 15     2
# 14     2
# 18     1
# Name: ani_milk_month, dtype: int64
# 6
# 27
# 6     37
# 0     30
# 9     13
# 1      9
# 7      5
# 8      4
# 13     2
# 12     1
# 10     1
# Name: ani_milk_month, dtype: int64
# 6
# 28
# 6     80
# 0     12
# 7      7
# 15     3
# 14     3
# 12     3
# 9      3
# 1      3
# 13     2
# 11     2
# 5      2
# 17     1
# 8      1
# 4      1
# Name: ani_milk_month, dtype: int64
# 6
# 29
# 6     81
# 0     54
# 7     25
# 8     14
# 1     10
# 10     6
# 9      6
# 12     4
# 5      2
# 4      2
# 3      2
# 2      2
# 16     1
# 15     1
# 14     1
# Name: ani_milk_month, dtype: int64
# 6
# 30
# 6    42
# 0    24
# 7     5
# 9     3
# 8     1
# Name: ani_milk_month, dtype: int64
# 6
# 31
# 6     62
# 0     43
# 7     29
# 5     13
# 8     12
# 4      6
# 9      5
# 3      5
# 10     2
# 12     1
# 2      1
# Name: ani_milk_month, dtype: int64
# 6
# 32
# 6     57
# 0     37
# 7     28
# 9     11
# 8      8
# 1      7
# 12     3
# 10     3
# 14     2
# 5      2
# 20     1
# 17     1
# 16     1
# 4      1
# Name: ani_milk_month, dtype: int64
# 6
# 33
# 6     47
# 0     14
# 8      7
# 12     6
# 9      5
# 7      3
# 11     1
# 1      1
# Name: ani_milk_month, dtype: int64
# 6
# 34
# 7    58
# 0    43
# 6    40
# 8    19
# 9     3
# Name: ani_milk_month, dtype: int64
# 7
# 35
# 6     71
# 0     47
# 7     31
# 5     17
# 8     11
# 4     11
# 10     5
# 9      4
# Name: ani_milk_month, dtype: int64
# 6
# 36
# 6     32
# 7     29
# 0     28
# 5     16
# 4     11
# 8      9
# 14     6
# 9      5
# 18     4
# 12     4
# 16     2
# 24     2
# 25     1
# 11     1
# 15     1
# 19     1
# 21     1
# 22     1
# 13     1
# Name: ani_milk_month, dtype: int64
# 6
# 37
# 7     111
# 0      57
# 6      33
# 8      15
# 5      11
# 9       6
# 4       4
# 10      1
# 1       1
# Name: ani_milk_month, dtype: int64
# 7
# 38
# 6    55
# 7    53
# 0    43
# 8    18
# 9    12
# 5    10
# 4     6
# 3     3
# Name: ani_milk_month, dtype: int64
# 6
# 39
# 0    51
# 6    49
# 7    46
# 5    12
# 8    11
# 4     1
# Name: ani_milk_month, dtype: int64
# 0
# 40
# 0    46
# 7    36
# 6    36
# 8    21
# 5     9
# 4     2
# Name: ani_milk_month, dtype: int64
# 0
# 41
# 7    85
# 0    61
# 6    47
# 8    18
# 4    14
# 5    13
# 2    12
# 3     6
# Name: ani_milk_month, dtype: int64
# 7
# 42
# 7    77
# 0    45
# 6    40
# 8    27
# 5    12
# 9     3
# 4     3
# 3     1
# Name: ani_milk_month, dtype: int64
# 7
# 43
# 6     85
# 7     46
# 0     26
# 5     20
# 4     13
# 9      4
# 10     3
# 8      1
# Name: ani_milk_month, dtype: int64
# 6
# 44
# 7    56
# 6    56
# 0    42
# 8    12
# 9     5
# 5     1
# 4     1
# Name: ani_milk_month, dtype: int64
# 7
# 45
# 6    68
# 7    53
# 5    41
# 0    41
# 4    20
# 8     9
# Name: ani_milk_month, dtype: int64
# 6

# %%
for i in data['district_code'].unique():
    x = data['ani_milk_month'][data[(data['district_code'] == i) & (data['ani_milk_month'] != -1)].index].value_counts()
    y = x[x == x.max()].index.tolist()
    data['ani_milk_month'] = data['ani_milk_month'].fillna(y[0])

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['semisolid_month_or_day'][data[(data['district_code'] == i) & (data['semisolid_month_or_day'] != -1)].index].value_counts()
    print(x)
    y = x[x == x.max()].index.tolist()
    print(y[0])
    data.loc[((data['district_code'] == i) & (data['semisolid_month_or_day'] == -1)), 'semisolid_month_or_day'] = y[0]
# Out:
# 1
# 6     83
# 9     51
# 0     49
# 10    38
# 7     35
# 8     26
# 12     7
# 11     5
# 5      5
# 4      2
# 15     1
# Name: semisolid_month_or_day, dtype: int64
# 6
# 2
# 0     32
# 6     22
# 10    13
# 12     9
# 16     6
# 9      5
# 14     3
# 18     2
# 7      2
# 13     1
# 11     1
# 8      1
# 1      1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 3
# 6     53
# 0     30
# 1     10
# 10     7
# 9      5
# 8      5
# 12     4
# 15     3
# 14     3
# 13     3
# 11     3
# 16     2
# 7      2
# 20     1
# 18     1
# 5      1
# Name: semisolid_month_or_day, dtype: int64
# 6
# 4
# 0     41
# 10    33
# 9     26
# 6     20
# 12    17
# 8     13
# 11     6
# 16     4
# 7      3
# 26     1
# 19     1
# 18     1
# 14     1
# 1      1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 5
# 0     38
# 6     22
# 10    15
# 9      6
# 15     5
# 8      3
# 12     2
# 1      2
# 16     1
# 7      1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 6
# 6     53
# 9     32
# 8     31
# 0     29
# 12    18
# 10    16
# 7     12
# 11     5
# 16     3
# 18     2
# 17     2
# 13     2
# 1      2
# 15     1
# 14     1
# 5      1
# Name: semisolid_month_or_day, dtype: int64
# 6
# 7
# 0     60
# 6     54
# 10    16
# 9     11
# 7     10
# 16     6
# 12     4
# 14     2
# 8      2
# 20     1
# 18     1
# 13     1
# 3      1
# 1      1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 8
# 6     49
# 7     46
# 8     40
# 0     30
# 10    26
# 9     20
# 12     8
# 5      7
# Name: semisolid_month_or_day, dtype: int64
# 6
# 9
# 8     83
# 9     52
# 0     41
# 7     26
# 6     21
# 10    14
# 5      2
# 11     1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 10
# 0     41
# 7     38
# 6     37
# 8     25
# 9     22
# 5      6
# 11     3
# 10     3
# 13     1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 11
# 8     90
# 0     55
# 7     44
# 6     39
# 9     24
# 10    12
# 5      4
# 11     1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 12
# 8     79
# 0     67
# 7     49
# 6     35
# 9     28
# 5      9
# 10     2
# Name: semisolid_month_or_day, dtype: int64
# 8
# 13
# 0    62
# 8    42
# 7    28
# 9    18
# 6    12
# 5     2
# Name: semisolid_month_or_day, dtype: int64
# 0
# 14
# 0     46
# 8     39
# 10    24
# 9     14
# 6      6
# 7      4
# 15     3
# 11     3
# 12     2
# 13     1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 15
# 0     49
# 6     37
# 8     35
# 9     28
# 7     22
# 10    15
# 11    14
# 5      2
# Name: semisolid_month_or_day, dtype: int64
# 0
# 16
# 7     61
# 8     57
# 0     48
# 9     45
# 6     15
# 10     2
# 14     1
# 12     1
# 11     1
# Name: semisolid_month_or_day, dtype: int64
#
1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 37
# 8     109
# 0      60
# 7      28
# 6      19
# 9      14
# 10      4
# 5       4
# 1       1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 38
# 7     55
# 0     52
# 8     46
# 9     22
# 10    15
# 12     4
# 6      4
# 11     2
# Name: semisolid_month_or_day, dtype: int64
# 7
# 39
# 8     78
# 0     44
# 7     24
# 6     16
# 10     5
# 9      2
# 5      1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 40
# 0     59
# 8     38
# 7     17
# 10    12
# 6     11
# 9      9
# 12     3
# 11     1
# Name: semisolid_month_or_day, dtype: int64
# 0
# 41
# 8    111
# 0     76
# 7     27
# 6     24
# 9     13
# 5      5
# Name: semisolid_month_or_day, dtype: int64
# 8
# 42
# 8     74
# 0     46
# 9     28
# 7     24
# 10    19
# 6      8
# 5      6
# 11     3
# Name: semisolid_month_or_day, dtype: int64
# 8
# 43
# 8     59
# 7     57
# 0     34
# 9     25
# 6     14
# 10     4
# 11     3
# 12     1
# 5      1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 44
# 8     54
# 0     44
# 7     38
# 6     18
# 10    10
# 9      7
# 11     1
# 5      1
# Name: semisolid_month_or_day, dtype: int64
# 8
# 45
# 7    74
# 8    48
# 0    41
# 6    40
# 5    21
# 9     8
# Name: semisolid_month_or_day, dtype: int64
# 7

# %%
for i in data['district_code'].unique():
    x = data['semisolid_month_or_day'][data[(data['district_code'] == i) & (data['semisolid_month_or_day'] != -1)].index].value_counts()
    y = x[x == x.max()].index.tolist()
    data['semisolid_month_or_day'] = data['semisolid_month_or_day'].fillna(y[0])

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['solid_month'][data[(data['district_code'] == i) & (data['solid_month'] != -1)].index].value_counts()
    print(x)
    y = x[x == x.max()].index.tolist()
    print(y[0])
    data.loc[((data['district_code'] == i) & (data['solid_month'] == -1)), 'solid_month'] = y[0]
# Out:
# 1
# 7     75
# 0     63
# 12    49
# 10    35
# 11    32
# 9     15
# 8     11
# 6     10
# 14     5
# 13     2
# 5      2
# 16     1
# 15     1
# 4      1
# Name: solid_month, dtype: int64
# 7
# 2
# 0     33
# 7     22
# 11    11
# 12     5
# 23     3
# 22     3
# 20     3
# 10     3
# 26     2
# 25     2
# 14     2
# 1      1
# 9      1
# 32     1
# 15     1
# 30     1
# 24     1
# 28     1
# 29     1
# 18     1
# Name: solid_month, dtype: int64
# 0
# 3
# 7     52
# 0     33
# 1     10
# 12     8
# 18     7
# 10     7
# 8      4
# 14     3
# 24     2
# 15     2
# 20     1
# 17     1
# 16     1
# 11     1
# 9      1
# Name: solid_month, dtype: int64
# 7
# 4
# 0     51
# 12    39
# 7     20
# 10    18
# 11    12
# 9      8
# 15     6
# 14     2
# 13     2
# 8      2
# 22     1
# 17     1
# 16     1
# 25     1
# 6      1
# 1      1
# 26     1
# Name: solid_month, dtype: int64
# 0
# 5
# 0     40
# 7     22
# 12    15
# 15     9
# 10     3
# 20     1
# 19     1
# 16     1
# 11     1
# 9      1
# 1      1
# Name: solid_month, dtype: int64
# 0
# 6
# 7     54
# 0     38
# 12    32
# 10    21
# 9     18
# 14    12
# 8      7
# 15     6
# 13     5
# 11     3
# 18     2
# 16     2
# 20     2
# 1      2
# 26     1
# 19     1
# 22     1
# 25     1
# 27     1
# Name: solid_month, dtype: int64
# 7
# 7
# 0     73
# 7     50
# 12    23
# 9      3
# 14     3
# 24     2
# 20     2
# 18     2
# 8      2
# 28     2
# 10     2
# 1      1
# 92     1
# 17     1
# 22     1
# 26     1
# 16     1
# Name: solid_month, dtype: int64
# 0
# 8
# 12    48
# 8     43
# 7     40
# 0     34
# 9     23
# 10    16
# 11    11
# 6     10
# 13     1
# Name: solid_month, dtype: int64
# 12
# 9
# 8     61
# 9     51
# 0     45
# 10    29
# 7     26
# 11    14
# 12    10
# 6      4
# Name: solid_month, dtype: int64
# 8
# 10
# 0     47
# 8     33
# 7     33
# 6     24
# 9     17
# 10    12
# 11     8
# 18     1
# 5      1
# Name: solid_month, dtype: int64
# 0
# 11
# 0     70
# 8     58
# 7     44
# 10    29
# 9     28
# 11    16
# 12    15
# 6      9
# Name: solid_month, dtype: int64
# 0
# 12
# 0     69
# 9     61
# 8     57
# 7     45
# 10    22
# 6     13
# 13     1
# 12     1
# Name: solid_month, dtype: int64
# 0
# 13
# 0     62
# 8     44
# 7     24
# 10    13
# 9     11
# 6      8
# 5      2
# Name: solid_month, dtype: int64
# 0
# 14
# 0     55
# 10    42
# 12    12
# 11    12
# 9     10
# 8      6
# 24     2
# 20     1
# 18     1
# 15     1
# Name: solid_month, dtype: int64
# 0
# 15
# 0     53
# 11    42
# 7     35
# 8     29
# 9     18
# 10    17
# 6      5
# 12     2
# 13     1
# Name: solid_month, dtype: int64
# 0
# 16
# 0     61
# 9     49
# 8     48
# 10    37
# 7     16
# 12    12
# 11     4
# 14     2
# 16     1
# Name: solid_month, dtype: int64
# 0
# 17
# 9     58
# 0     52
# 10    38
# 8     27
# 7     13
# 11     6
# 15     1
# 14     1
# 12     1
# Name: solid_month, dtype: int64
# 9
# 18
# 0     14
# 7     12
# 12     7
# 16     3
# 11     3
# 26     2
# 14     2
# 1      1
# Name: solid_month, dtype: int64
# 0
# 19
# 7     26
# 12    15
# 0     13
# 14     4
# 18     3
# 11     3
# 10     3
# 9      3
# 22     2
# 1      2
# 20     1
# 2      1
# Name: solid_month, dtype: int64
# 7
# 20
# 7     26
# 0     22
# 18     5
# 9      5
# 16     4
# 15     4
# 12     2
# 11     2
# 10     2
# 17     1
# 14     1
# 6      1
# Name: solid_month, dtype: int64
# 7
# 21
# 7     55
# 0     45
# 12    14
# 15     9
# 14     8
# 18     6
# 11     6
# 9      6
# 16     5
# 10     5
# 17     3
# 13     2
# 8      2
# 2      2
# 1      1
# Name: solid_month, dtype: int64
# 7
# 22
# 7     33
# 0     31
# 12    12
# 11     6
# 10     5
# 21     5
# 26     2
# 23     2
# 22     2
# 27     2
# 16     2
# 14     1
# 28     1
# 17     1
# 20     1
# 24     1
# 25     1
# 18     1
# Name: solid_month, dtype: int64
# 7
# 23
# 7     104
# 0      25
# 15     19
# 13     13
# 9      13
# 12      9
# 10      9
# 16      7
# 14      7
# 8       6
# 18      4
# 11      4
# 6       1
# Name: solid_month, dtype: int64
# 7
# 24
# 11    26
# 7     25
# 12    21
# 0     15
# 21     5
# 10     5
# 13     2
# 22     2
# 9      2
# 14     2
# 26     1
# 25     1
# 17     1
# 18     1
# 20     1
# 24     1
# 16     1
# Name: solid_month, dtype: int64
# 11
# 25
# 7     29
# 12    20
# 11     8
# 14     5
# 0      3
# 18     2
# 16     2
# 15     1
# 13     1
# 10     1
# 9      1
# Name: solid_month, dtype: int64
# 7
# 26
# 0     57
# 7     45
# 9     36
# 12    22
# 11    22
# 10    20
# 15    16
# 8     15
# 14    11
# 18     7
# 16     2
# 13     2
# 1      2
# 22     1
# 19     1
# 6      1
# Name: solid_month, dtype: int64
# 0
# 27
# 0     36
# 7     31
# 1      9
# 12     7
# 18     3
# 14     3
# 25     2
# 23     2
# 22     2
# 8      2
# 6      2
# 26     1
# 21     1
# 10     1
# Name: solid_month, dtype: int64
# 0
# 28
# 7     74
# 0     15
# 11     6
# 16     5
# 18     4
# 12     3
# 8      3
# 1      3
# 21     2
# 15     2
# 10     2
# 20     1
# 17     1
# 14     1
# 9      1
# Name: solid_month, dtype: int64
# 7
# 29
# 7     66
# 0     40
# 12    22
# 8     19
# 10    14
# 11     9
# 6      8
# 1      8
# 9      5
# 15     4
# 20     3
# 18     3
# 16     2
# 13     1
# 14     1
# 2      1
# 24     1
# Name: solid_month, dtype: int64
# 7
# 30
# 7     36
# 0     24
# 12     8
# 8      3
# 10     2
# 9      2
# Name: solid_month, dtype: int64
# 7
# 31
# 0     68
# 9     40
# 8     16
# 7     16
# 10    14
# 12    10
# 11     7
# 6      4
# 14     2
# 13     2
# Name: solid_month, dtype: int64
# 0
# 32
# 0     56
# 7     35
# 12    17
# 10     8
# 1      7
# 8      6
# 11     6
# 14     6
# 9      5
# 16     4
# 20     3
# 6      2
# 22     2
# 13     1
# 23     1
# 15     1
# 5      1
# 25     1
# Name: solid_month, dtype: int64
# 0
# 33
# 7     39
# 0     20
# 12    11
# 10     3
# 9      3
# 15     2
# 1      2
# 20     1
# 19     1
# 16     1
# 11     1
# Name: solid_month, dtype: int64
# 7
# 34
# 0     64
# 7     34
# 8     17
# 12    14
# 10    11
# 11    10
# 9      7
# 6      5
# 14     1
# Name: solid_month, dtype: int64
# 0
# 35
# 0     56
# 7     55
# 9     30
# 8     28
# 10    15
# 6      9
# 15     2
# 12     1
# 11     1
# Name: solid_month, dtype: int64
# 0
# 36
# 0     58
# 12    19
# 9     16
# 8     14
# 7     11
# 11    10
# 14     5
# 18     4
# 6      4
# 22     3
# 16     2
# 15     2
# 24     2
# 25     1
# 13     1
# 21     1
# 23     1
# 26     1
# Name: solid_month, dtype: int64
# 0
# 37
# 9     88
# 0     73
# 8     40
# 7     18
# 10     8
# 6      6
# 14     3
# 11     1
# 1      1
# Name: solid_month, dtype: int64
# 9
# 38
# 0     62
# 8     45
# 9     37
# 10    30
# 7     19
# 12     6
# 11     1
# Name: solid_month, dtype: int64
# 0
# 39
# 0     55
# 8     40
# 10    18
# 11    14
# 7     14
# 12    12
# 9     10
# 6      7
# Name: solid_month, dtype: int64
# 0
# 40
# 0     66
# 8     34
# 9     11
# 10    10
# 11     9
# 7      8
# 6      7
# 12     5
# Name: solid_month, dtype: int64
# 0
# 41
# 9     103
# 0      82
# 8      29
# 7      25
# 6       6
# 10      5
# 11      4
# 19      1
# 3       1
# Name: solid_month, dtype: int64
# 9
# 42
# 8     58
# 0     56
# 9     55
# 11    19
# 10    12
# 5      4
# 12     2
# 7      2
# Name: solid_month, dtype: int64
# 8
# 43
# 9     96
# 0     41
# 8     23
# 7     20
# 11     9
# 6      4
# 13     2
# 12     2
# 14     1
# Name: solid_month, dtype: int64
# 9
# 44
# 0     48
# 7     36
# 8     26
# 10    25
# 9     17
# 11     8
# 12     7
# 6      4
# 13     1
# 2      1
# Name: solid_month, dtype: int64
# 0
# 45
# 8    69
# 7    52
# 9    47
# 0    43
# 6    21
# Name: solid_month, dtype: int64
# 8

# %%
for i in data['district_code'].unique():
    x = data['solid_month'][data[(data['district_code'] == i) & (data['solid_month'] != -1)].index].value_counts()
    y = x[x == x.max()].index.tolist()
    data['solid_month'] = data['solid_month'].fillna(y[0])

# %%
for i in data['district_code'].unique():
    print(i)
    x = data['vegetables_month_or_day'][data[(data['district_code'] == i) & (data['vegetables_month_or_day'] != -1)].index].value_counts()
    print(x)
    y = x[x == x.max()].index.tolist()
    print(y[0])
    data.loc[((data['district_code'] == i) & (data['vegetables_month_or_day'] == -1)), 'vegetables_month_or_day'] = y[0]
# Out:
# 1
# 8     75
# 0     63
# 12    35
# 13    34
# 10    33
# 11    14
# 7     13
# 9     10
# 6      9
# 14     5
# 15     3
# 18     2
# 16     2
# 5      1
# 4      1
# 2      1
# 20     1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 2
# 0     36
# 8     22
# 10    16
# 24     4
# 16     2
# 29     2
# 27     2
# 26     2
# 12     2
# 9      1
# 11     1
# 34     1
# 18     1
# 21     1
# 33     1
# 25     1
# 28     1
# 32     1
# 22     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 3
# 8     52
# 0     43
# 12    10
# 18     6
# 10     5
# 15     3
# 22     2
# 20     2
# 14     2
# 9      1
# 1      1
# 6      1
# 26     1
# 11     1
# 24     1
# 16     1
# 13     1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 4
# 0     53
# 10    39
# 12    25
# 8     21
# 11     7
# 15     6
# 14     5
# 21     2
# 16     2
# 13     2
# 28     1
# 26     1
# 22     1
# 20     1
# 18     1
# 1      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 5
# 0     42
# 8     22
# 10    13
# 15     9
# 14     3
# 11     3
# 12     2
# 25     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 6
# 8     54
# 0     43
# 12    32
# 10    19
# 14    11
# 16    10
# 15    10
# 11     6
# 7      4
# 13     3
# 18     3
# 17     2
# 20     2
# 9      2
# 5      2
# 28     2
# 26     1
# 22     1
# 24     1
# 6      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 7
# 0     77
# 8     49
# 10    19
# 12     8
# 9      4
# 25     3
# 24     2
# 22     2
# 19     2
# 14     2
# 30     1
# 26     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 8
# 8     59
# 12    50
# 0     34
# 9     28
# 10    22
# 7     12
# 14     6
# 16     4
# 13     4
# 15     3
# 11     2
# 6      2
# Name: vegetables_month_or_day, dtype: int64
# 8
# 9
# 9     70
# 0     47
# 10    40
# 8     33
# 11    16
# 12    11
# 7      9
# 14     7
# 13     5
# 17     1
# 15     1
# Name: vegetables_month_or_day, dtype: int64
# 9
# 10
# 0     49
# 8     33
# 9     29
# 6     17
# 10    16
# 7     15
# 11    14
# 18     1
# 12     1
# 5      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 11
# 8     75
# 0     72
# 12    37
# 9     33
# 10    24
# 11    16
# 7     11
# 6      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 12
# 0     69
# 8     67
# 10    55
# 9     37
# 7     22
# 11    17
# 13     2
# Name: vegetables_month_or_day, dtype: int64
# 0
# 13
# 0     65
# 8     35
# 9     20
# 7     18
# 11     9
# 6      8
# 10     7
# 5      2
# Name: vegetables_month_or_day, dtype: int64
# 0
# 14
# 0     61
# 11    45
# 10    13
# 13     7
# 12     7
# 9      5
# 24     2
# 20     1
# 15     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 15
# 0     53
# 11    48
# 8     39
# 7     18
# 9     17
# 10    15
# 12     7
# 6      3
# 13     2
# Name: vegetables_month_or_day, dtype: int64
# 0
# 16
# 0     64
# 9     42
# 10    40
# 12    33
# 8     31
# 11    17
# 16     2
# 18     1
# 14     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 17
# 10    58
# 0     52
# 9     33
# 11    30
# 8     12
# 7      7
# 12     3
# 15     1
# 14     1
# Name: vegetables_month_or_day, dtype: int64
# 10
# 18
# 0     14
# 8     12
# 10     8
# 16     3
# 20     2
# 28     1
# 22     1
# 18     1
# 14     1
# 12     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 19
# 8     26
# 0     19
# 12    14
# 20     3
# 25     2
# 18     2
# 11     2
# 10     2
# 9      2
# 16     1
# 15     1
# 14     1
# 2      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 20
# 8     26
# 0     21
# 10     9
# 18     6
# 16     3
# 17     2
# 11     2
# 9      2
# 19     1
# 15     1
# 12     1
# 7      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 21
# 8     58
# 0     52
# 10    12
# 18    11
# 12    10
# 16     7
# 14     4
# 11     4
# 15     3
# 17     2
# 9      2
# 19     1
# 13     1
# 5      1
# 2      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 22
# 0     35
# 8     33
# 12    14
# 10     7
# 22     4
# 28     3
# 25     3
# 26     2
# 24     2
# 20     2
# 18     2
# 17     1
# 16     1
# 4      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 23
# 8     104
# 15     26
# 0      26
# 14     12
# 10     12
# 16      7
# 12      7
# 11      7
# 13      6
# 9       6
# 18      4
# 17      2
# 20      1
# 3       1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 24
# 13    25
# 8     25
# 0     17
# 14    16
# 12    10
# 23     4
# 25     3
# 16     3
# 22     2
# 10     2
# 28     1
# 27     1
# 20     1
# 3      1
# 2      1
# Name: vegetables_month_or_day, dtype: int64
# 13
# 25
# 8     29
# 14    11
# 10     7
# 11     5
# 18     4
# 13     4
# 15     3
# 0      3
# 17     2
# 16     2
# 12     2
# 4      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 26
# 0     60
# 12    45
# 8     45
# 10    29
# 18    19
# 11    17
# 15    14
# 9     10
# 7      7
# 20     3
# 14     3
# 16     2
# 13     2
# 6      2
# 22     1
# 19     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 27
# 0     47
# 8     33
# 6      4
# 10     3
# 26     2
# 24     2
# 20     2
# 18     2
# 12     2
# 25     1
# 22     1
# 16     1
# 13     1
# 11     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 28
# 8     74
# 0     18
# 10     9
# 18     8
# 16     3
# 23     2
# 17     2
# 9      2
# 25     1
# 13     1
# 12     1
# 11     1
# 7      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 29
# 8     67
# 0     53
# 12    27
# 10    26
# 15     8
# 18     5
# 13     5
# 24     3
# 16     3
# 9      3
# 20     2
# 22     1
# 14     1
# 11     1
# 7      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 30
# 8     36
# 0     23
# 10    12
# 12     2
# 9      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 31
# 0     69
# 10    25
# 11    23
# 12    21
# 8     12
# 9     10
# 7      9
# 13     7
# 15     1
# 14     1
# 6      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 32
# 0     60
# 8     37
# 10    12
# 12    12
# 16     8
# 11     7
# 7      5
# 14     5
# 20     3
# 15     2
# 18     2
# 24     2
# 26     1
# 13     1
# 17     1
# 9      1
# 23     1
# 6      1
# 28     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 33
# 8     39
# 0     21
# 10     8
# 15     3
# 12     2
# 11     2
# 9      2
# 3      2
# 24     1
# 22     1
# 21     1
# 19     1
# 1      1
# Name: vegetables_month_or_day, dtype: int64
# 8
# 34
# 0     65
# 7     30
# 12    19
# 8     17
# 10    11
# 11    10
# 9      6
# 6      4
# 14     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 35
# 0     59
# 7     51
# 10    33
# 9     24
# 8     18
# 11     7
# 18     2
# 12     2
# 13     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 36
# 0     58
# 9     17
# 13    15
# 8     15
# 11     9
# 12     7
# 7      6
# 10     6
# 18     5
# 14     4
# 16     3
# 22     3
# 24     2
# 26     1
# 15     1
# 21     1
# 25     1
# 28     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 37
# 0     92
# 10    61
# 8     35
# 9     31
# 7      8
# 11     4
# 14     3
# 6      2
# 12     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 38
# 0     65
# 9     40
# 8     32
# 10    28
# 12    14
# 7     13
# 11     8
# Name: vegetables_month_or_day, dtype: int64
# 0
# 39
# 0     55
# 9     34
# 8     20
# 11    18
# 10    18
# 12    17
# 6      5
# 7      3
# Name: vegetables_month_or_day, dtype: int64
# 0
# 40
# 0     72
# 8     22
# 9     18
# 10    11
# 11     9
# 7      6
# 6      6
# 12     4
# 14     1
# 13     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 41
# 0     86
# 9     70
# 10    47
# 8     33
# 11    10
# 7      6
# 6      3
# 19     1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 42
# 0     59
# 9     57
# 10    48
# 11    17
# 8     12
# 12     8
# 5      4
# 14     2
# 7      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 43
# 11    74
# 0     47
# 9     32
# 10    13
# 8     12
# 7     12
# 15     3
# 14     3
# 13     2
# Name: vegetables_month_or_day, dtype: int64
# 11
# 44
# 0     48
# 8     35
# 10    30
# 9     15
# 7     14
# 11    13
# 12     9
# 15     2
# 14     2
# 6      2
# 2      1
# 1      1
# Name: vegetables_month_or_day, dtype: int64
# 0
# 45
# 8     65
# 9     57
# 0     44
# 10    33
# 7     33
# Name: vegetables_month_or_day, dtype: int64
# 8

# %%
for i in data['district_code'].unique():
    x = data['vegetables_month_or_day'][data[(data['district_code'] == i) & (data['vegetables_month_or_day'] != -1)].index].value_counts()
    y = x[x == x.max()].index.tolist()
    data['vegetables_month_or_day'] = data['vegetables_month_or_day'].fillna(y[0])

# %%
print(data['water_month'][data[data['water_month'] == -1].index].value_counts())
print(data['ani_milk_month'][data[data['ani_milk_month'] == -1].index].value_counts())
print(data['semisolid_month_or_day'][data[data['semisolid_month_or_day'] == -1].index].value_counts())
print(data['solid_month'][data[data['solid_month'] == -1].index].value_counts())
print(data['vegetables_month_or_day'][data[data['vegetables_month_or_day'] == -1].index].value_counts())
# Out:
# Series([], Name: water_month, dtype: int64)
# Series([], Name: ani_milk_month, dtype: int64)
# Series([], Name: semisolid_month_or_day, dtype: int64)
# Series([], Name: solid_month, dtype: int64)
# Series([], Name: vegetables_month_or_day, dtype: int64)

# %%
data = data.drop('district_code', axis=1)

# %%
data.columns.values
# Out:
# array(['state_code', 'record_code_iodine', 'sex', 'age_code', 'age',
#        'weight_in_kg', 'length_height_cm', 'haemoglobin_level',
#        'first_breast_feeding', 'is_cur_breast_feeding',
#        'day_or_month_for_breast_feeding_',
#        'day_or_month_for_breast_feeding', 'water_month', 'ani_milk_month',
#        'semisolid_month_or_day', 'solid_month', 'vegetables_month_or_day',
#        'illness_type', 'treatment_type'], dtype=object)

# %%
data.shape
# Out:
# (14661, 19)

# %%
for i in data[data['day_or_month_for_breast_feeding_'] == 'D'].index:
    print(i,' ',data['day_or_month_for_breast_feeding_'][i],' ',data['day_or_month_for_breast_feeding'][i])
    if data['day_or_month_for_breast_feeding'][i] < 15:
        data['day_or_month_for_breast_feeding'][i] = 0
    else :
        data['day_or_month_for_breast_feeding'][i] = 1
    print(i,' ',data['day_or_month_for_breast_feeding_'][i],' ',data['day_or_month_for_breast_feeding'][i])
# Out:
# 1466   D   0
# 1466   D   0
# 3612   D   0
# 3612   D   0
# 4346
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#   D   6
# 4346   D   0
# 5677   D   0
# 5677   D   0
# 6585   D   15
# 6585   D   1
# 6635   D   15
# 6635   D   1
# 8595   D   1
# 8595   D   0
# 9428   D   0
# 9428   D   0
# 9429   D   0
# 9429   D   0
# 9638   D   0
# 9638   D   0
# 9679   D   5
# 9679   D   0
# 13898   D   0
# 13898   D   0
# 14838   D   1
# 14838   D   0
# 16175   D   15
# 16175   D   1
# 18158   D   4
# 18158   D   0
# 18858   D   8
# 18858   D   0
# 19172   D   2
# 19172   D   0
# 19241   D   19
# 19241   D   1
# 20004   D   5
# 20004   D   0
# 21027   D   7
# 21027   D   0
# 23377   D   0
# 23377   D   0
# 24313   D   20
# 24313   D   1
# 24953   D   14
# 24953   D   0
# 25116   D   7
# 25116   D   0
# 27970   D   1
# 27970   D   0
# 28823   D   8
# 28823   D   0
# 32406   D   0
# 32406   D   0
# 32778   D   0
# 32778   D   0
# 33150   D   0
# 33150   D   0
# 33466   D   1
# 33466   D   0
# 34305   D   0
# 34305   D   0
# 34459   D   2
# 34459   D   0
# 35232   D   27
# 35232   D   1
# 42458   D   7
# 42458   D   0
# 44498   D   20
# 44498   D   1
# 58413   D   6
# 58413   D   0
# 58516   D   6
# 58516   D   0
# 61041   D   4
# 61041   D   0
# 70803   D   6
# 70803   D   0
# 75564   D   17
# 75564   D   1
# 78676   D   28
# 78676   D   1
# 78677   D   29
# 78677   D   1
# 78715   D   8
# 78715   D   0
# 78749   D   27
# 78749   D   1
# 78801   D   15
# 78801   D   1
# 88916   D   16
# 88916   D   1
# 92405   D   15
# 92405   D   1
# 101606   D   40
# 101606   D   1
# 106721   D   3
# 106721   D   0
# 111469   D   0
# 111469   D   0
# 111701   D   2
# 111701   D   0
# 112011   D   0
# 112011   D   0
# 113755   D   0
# 113755   D   0
# 114025   D   4
# 114025   D   0
# 115078   D   24
# 115078   D   1
# 118583   D   0
# 118583   D   0
# 119767   D   6
# 119767   D   0
# 121235   D   8
# 121235   D   0
# 121869   D   0
# 121869   D   0
# 122386   D   0
# 122386   D   0
# 123881   D   0
# 123881   D   0
# 126346   D   0
# 126346   D   0
# 127054   D   0
# 127054   D   0
# 130282   D   0
# 130282   D   0
# 133583   D   0
# 133583   D   0
# 133660   D   99
# 133660   D   1
# 133818   D   0
# 133818   D   0
# 133819   D   15
# 133819   D   1
# 134177   D   10
# 134177   D   0
# 134217   D   16
# 134217   D   1
# 135246   D   0
# 135246   D   0
# 135293   D   0
# 135293   D   0
# 135356   D   0
# 135356   D   0
# 135444   D   0
# 135444   D   0
# 135480   D   0
# 135480   D   0
# 135498   D   0
# 135498   D   0
# 136198   D   0
# 136198   D   0
# 138930   D   0
# 138930   D   0
# 140147   D   0
# 140147   D   0
# 149994   D   11
# 149994   D   0
# 150743   D   8
# 150743   D   0
# 155573   D   0
# 155573   D   0
# 155867   D   0
# 155867   D   0
# 160424   D   23
# 160424   D   1
# 160443   D   7
# 160443   D   0
# 163447   D   0
# 163447   D   0
# 164205   D   3
# 164205   D   0
# 169299   D   7
# 169299   D   0
# 173305   D   15
# 173305   D   1
# 176602   D   5
# 176602   D   0
# 180333   D   7
# 180333   D   0
# 183748   D   0
# 183748   D   0
# 183794   D   7
# 183794   D   0
# 187394   D   12
# 187394   D   0
# 208393   D   25
# 208393   D   1
# 213543   D   8
# 213543   D   0
# 223831   D   11
# 223831   D   0
# 226185   D   26
# 226185   D   1
# 227776   D   24
# 227776   D   1
# 235939   D   10
# 235939   D   0
# 236580   D   21
# 236580   D   1
# 242348   D   25
# 242348   D   1
# 257036   D   12
# 257036   D   0
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in data[data['age_code'] == 'Y'].index:
    x = data['age'][i]
    print(i,' ',data['age_code'][i],' ',data['age'][i])
    data['age'][i] = x*12
    print(i,' ',data['age_code'][i],' ',data['age'][i])
# Out:
# 37   Y   1
# 37   Y   12
# 85   Y   1
# 85   Y   12
# 86   Y
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 1
# 86   Y   12
# 122   Y   3
# 122   Y   36
# 135   Y   1
# 135   Y   12
# 202   Y   2
# 202   Y   24
# 226   Y   4
# 226   Y   48
# 230   Y   4
# 230   Y   48
# 233   Y   2
# 233   Y   24
# 244   Y   4
# 244   Y   48
# 250   Y   3
# 250   Y   36
# 251   Y   2
# 251   Y   24
# 263   Y   4
# 263   Y   48
# 279   Y   5
# 279   Y   60
# 280   Y   2
# 280   Y   24
# 281   Y   2
# 281   Y   24
# 314   Y   4
# 314   Y   48
# 320   Y   5
# 320   Y   60
# 360   Y   5
# 360   Y   60
# 384   Y   2
# 384   Y   24
# 386   Y   2
# 386   Y   24
# 392   Y   1
# 392   Y   12
# 501   Y   2
# 501   Y   24
# 535   Y   3
# 535   Y   36
# 573   Y   3
# 573   Y   36
# 588   Y   3
# 588   Y   36
# 603   Y   3
# 603   Y   36
# 626   Y   4
# 626   Y   48
# 661   Y   3
# 661   Y   36
# 677   Y   4
# 677   Y   48
# 719   Y   3
# 719   Y   36
# 744   Y   4
# 744   Y   48
# 752   Y   1
# 752   Y   12
# 753   Y   4
# 753   Y   48
# 798   Y   3
# 798   Y   36
# 799   Y   1
# 799   Y   12
# 807   Y   3
# 807   Y   36
# 808   Y   2
# 808   Y   24
# 809   Y   1
# 809   Y   12
# 6757   Y   2
# 6757   Y   24
# 6781   Y   3
# 6781   Y   36
# 6793   Y   2
# 6793   Y   24
# 6799   Y   2
# 6799   Y   24
# 6803   Y   2
# 6803   Y   24
# 6811   Y   2
# 6811   Y   24
# 6818   Y   3
# 6818   Y   36
# 6819   Y   3
# 6819   Y   36
# 6887   Y   3
# 6887   Y   36
# 6888   Y   3
# 6888   Y   36
# 6929   Y   3
# 6929   Y   36
# 6947   Y   3
# 6947   Y   36
# 6970   Y   4
# 6970   Y   48
# 6988   Y   3
# 6988   Y   36
# 7005   Y   4
# 7005   Y   48
# 7035   Y   3
# 7035   Y   36
# 7044   Y   4
# 7044   Y   48
# 7052   Y   4
# 7052   Y   48
# 7053   Y   2
# 7053   Y   24
# 7069   Y   4
# 7069   Y   48
# 7070   Y   3
# 7070   Y   36
# 7075   Y   4
# 7075   Y   48
# 7081   Y   4
# 7081   Y   48
# 7098   Y   2
# 7098   Y   24
# 7104   Y   2
# 7104   Y   24
# 7109   Y   4
# 7109   Y   48
# 7113   Y   4
# 7113   Y   48
# 7224   Y   1
# 7224   Y   12
# 7227   Y   1
# 7227   Y   12
# 7228   Y   1
# 7228   Y   12
# 7245   Y   3
# 7245   Y   36
# 7246   Y   3
# 7246   Y   36
# 7333   Y   4
# 7333   Y   48
# 7341   Y   3
# 7341   Y   36
# 7347   Y   3
# 7347   Y   36
# 7381   Y   4
# 7381   Y   48
# 7386   Y   4
# 7386   Y   48
# 7411   Y   4
# 7411   Y   48
# 7421   Y   4
# 7421   Y   48
# 7437   Y   3
# 7437   Y   36
# 7443   Y   3
# 7443   Y   36
# 7463   Y   3
# 7463   Y   36
# 7477   Y   3
# 7477   Y   36
# 7507   Y   4
# 7507   Y   48
# 7508   Y   2
# 7508   Y   24
# 7511   Y   3
# 7511   Y   36
# 7546   Y   4
# 7546   Y   48
# 7569   Y   3
# 7569   Y   36
# 7576   Y   4
# 7576   Y   48
# 7577   Y   1
# 7577   Y   12
# 7683   Y   2
# 7683   Y   24
# 7689   Y   3
# 7689   Y   36
# 7758   Y   3
# 7758   Y   36
# 7814   Y   3
# 7814   Y   36
# 7887   Y   1
# 7887   Y   12
# 7945   Y   1
# 7945   Y   12
# 7962   Y   1
# 7962   Y   12
# 7963   Y   1
# 7963   Y   12
# 7978   Y   1
# 7978   Y   12
# 7981   Y   1
# 7981   Y   12
# 8004   Y   1
# 8004   Y   12
# 8016   Y   1
# 8016   Y   12
# 8030   Y   2
# 8030   Y   24
# 8038   Y   2
# 8038   Y   24
# 8040   Y   2
# 8040   Y   24
# 8064   Y   2
# 8064   Y   24
# 8066   Y   2
# 8066   Y   24
# 8143   Y   3
# 8143   Y   36
# 8148   Y   2
# 8148   Y   24
# 8167   Y   3
# 8167   Y   36
# 8169   Y   3
# 8169   Y   36
# 8192   Y   2
# 8192   Y   24
# 8200   Y   4
# 8200   Y   48
# 8201   Y   3
# 8201   Y   36
# 8211   Y   4
# 8211   Y   48
# 8212   Y   3
# 8212   Y   36
# 8225   Y   3
# 9674   Y   48
# 9701   Y   2
# 9701   Y   24
# 9721   Y   4
# 9721   Y   48
# 9722   Y   2
# 9722   Y   24
# 9795   Y   4
# 9795   Y   48
# 9796   Y   2
# 9796   Y   24
# 9848   Y   3
# 9848   Y   36
# 9877   Y   4
# 9877   Y   48
# 9888   Y   3
# 9888   Y   36
# 9904   Y   3
# 9904   Y   36
# 9981   Y   3
# 9981   Y   36
# 10009   Y   3
# 10009   Y   36
# 10012   Y   4
# 10012   Y   48
# 10013   Y   3
# 10013   Y   36
# 10052   Y   4
# 10052   Y   48
# 10114   Y   3
# 10114   Y   36
# 10121   Y   5
# 10121   Y   60
# 10129   Y   3
# 10129   Y   36
# 10156   Y   3
# 10156   Y   36
# 10178   Y   2
# 10178   Y   24
# 10227   Y   3
# 10227   Y   36
# 10233   Y   5
# 10233   Y   60
# 10234   Y   4
# 10234   Y   48
# 10235   Y   3
# 10235   Y   36
# 10244   Y   4
# 10244   Y   48
# 10316   Y   3
# 10316   Y   36
# 10362   Y   3
# 10362   Y   36
# 10366   Y   3
# 10366   Y   36
# 10432   Y   3
# 10432   Y   36
# 10433   Y   3
# 10433   Y   36
# 10457   Y   5
# 10457   Y   60
# 10458   Y   3
# 10458   Y   36
# 10479   Y   2
# 10479   Y   24
# 10523   Y   1
# 10523   Y   12
# 10581   Y   2
# 10581   Y   24
# 10602   Y   4
# 10602   Y   48
# 10606   Y   3
# 10606   Y   36
# 10649   Y   4
# 10649   Y   48
# 10655   Y   5
# 10655   Y   60
# 10688   Y   3
# 10688   Y   36
# 10692   Y   4
# 10692   Y   48
# 10697   Y   3
# 10697   Y   36
# 10753   Y   4
# 10753   Y   48
# 10767   Y   4
# 10767   Y   48
# 10770   Y   4
# 10770   Y   48
# 10815   Y   3
# 10815   Y   36
# 10831   Y   4
# 10831   Y   48
# 10840   Y   3
# 10840   Y   36
# 10845   Y   4
# 10845   Y   48
# 10859   Y   3
# 10859   Y   36
# 10900   Y   5
# 10900   Y   60
# 10930   Y   3
# 10930   Y   36
# 10966   Y   3
# 10966   Y   36
# 10973   Y   3
# 10973   Y   36
# 10989   Y   3
# 10989   Y   36
# 10994   Y   3
# 10994   Y   36
# 11033   Y   5
# 11033   Y   60
# 11056   Y   5
# 11056   Y   60
# 11096   Y   3
# 11096   Y   36
# 11100   Y   4
# 11100   Y   48
# 11114   Y   4
# 11114   Y   48
# 11224   Y   3
# 11224   Y   36
# 11292   Y   2
# 11292   Y   24
# 11400   Y   5
# 11400   Y   60
# 11401   Y   2
# 11401   Y   24
# 11413   Y   3
# 11413   Y   36
# 11449   Y   2
# 11449   Y   24
# 11532   Y   2
# 11532   Y   24
# 11559   Y   2
# 11559   Y   24
# 11571   Y   4
# 11571   Y   48
# 11621   Y   4
# 11621   Y   48
# 11625   Y   4
# 11625   Y   48
# 11646   Y   5
# 11646   Y   60
# 11667   Y   4
# 11667   Y   48
# 11668   Y   3
# 11668   Y   36
# 11680   Y   3
# 11680   Y   36
# 11690   Y   4
# 11690   Y   48
# 19436   Y   3
# 19436   Y   36
# 19443   Y   4
# 19443   Y   48
# 19444   Y   2
# 19444   Y   24
# 19449   Y   3
# 19449   Y   36
# 19461   Y   3
# 19461   Y   36
# 19497   Y   4
# 19497   Y   48
# 19506   Y   4
# 19506   Y   48
# 19507   Y   3
# 19507   Y   36
# 19531   Y   3
# 19531   Y   36
# 19540   Y   2
# 19540   Y   24
# 19554   Y   4
# 19554   Y   48
# 19577   Y   2
# 19577   Y   24
# 19589   Y   2
# 19589   Y   24
# 19614   Y   3
# 19614   Y   36
# 19672   Y   4
# 19672   Y   48
# 19686   Y   2
# 19686   Y   24
# 19711   Y   3
# 19711   Y   36
# 19723   Y   5
# 19723   Y   60
# 19724   Y   5
# 19724   Y   60
# 19733   Y   4
# 19733   Y   48
# 19769   Y   3
# 19769   Y   36
# 19778   Y   3
# 19778   Y   36
# 19790   Y   4
# 19790   Y   48
# 19857   Y   4
# 19857   Y   48
# 19871   Y   4
# 19871   Y   48
# 19874   Y   4
# 19874   Y   48
# 19875   Y   3
# 19875   Y   36
# 19887   Y   4
# 19887   Y   48
# 19893   Y   5
# 19893   Y   60
# 19987   Y   4
# 19987   Y   48
# 19988   Y   2
# 19988   Y   24
# 19999   Y   4
# 19999   Y   48
# 20003   Y   2
# 20003   Y   24
# 20021   Y   2
# 20021   Y   24
# 20025   Y   5
# 20025   Y   60
# 20026   Y   3
# 20026   Y   36
# 20054   Y   4
# 20054   Y   48
# 20064   Y   4
# 20064   Y   48
# 20065   Y   3
# 20065   Y   36
# 20071   Y   4
# 20071   Y   48
# 20125   Y   4
# 20125   Y   48
# 20133   Y   5
# 20133   Y   60
# 20140   Y   1
# 20140   Y   12
# 20200   Y   4
# 20200   Y   48
# 20226   Y   3
# 20226   Y   36
# 20241   Y   5
# 20241   Y   60
# 20261   Y   4
# 20261   Y   48
# 20262   Y   2
# 20262   Y   24
# 20286   Y   3
# 20286   Y   36
# 20297   Y   4
# 20297   Y   48
# 20298   Y   3
# 20298   Y   36
# 20299   Y   3
# 20299   Y   36
# 20300   Y   1
# 20300   Y   12
# 20313   Y   3
# 20313   Y   36
# 20317   Y   3
# 20317   Y   36
# 20393   Y   3
# 20393   Y   36
# 20402   Y   4
# 20402   Y   48
# 20426   Y   4
# 20426   Y   48
# 20487   Y   3
# 20487   Y   36
# 20535   Y   2
# 20535   Y   24
# 20543   Y   4
# 20543   Y   48
# 20602   Y   2
# 20602   Y   24
# 20614   Y   3
# 20614   Y   36
# 20629   Y   3
# 20629   Y   36
# 20641   Y   3
# 20641   Y   36
# 20688   Y   4
# 20688   Y   48
# 20705   Y   4
# 20705   Y   48
# 20730   Y   3
# 20730   Y   36
# 20787   Y   5
# 20787   Y   60
# 20788   Y   2
# 20788   Y   24
# 20810   Y   5
# 20810   Y   60
# 20823   Y   3
# 20823   Y   36
# 20827   Y   2
# 20827   Y   24
# 20831   Y   1
# 20831   Y   12
# 20943   Y   5
# 20943   Y   60
# 20956   Y   4
# 20956   Y   48
# 20969   Y   3
# 25620   Y   3
# 25620   Y   36
# 25707   Y   1
# 25707   Y   12
# 25782   Y   4
# 25782   Y   48
# 25797   Y   2
# 25797   Y   24
# 25801   Y   4
# 25801   Y   48
# 25826   Y   2
# 25826   Y   24
# 25869   Y   4
# 25869   Y   48
# 25878   Y   3
# 25878   Y   36
# 25914   Y   3
# 25914   Y   36
# 25955   Y   3
# 25955   Y   36
# 26008   Y   4
# 26008   Y   48
# 26011   Y   2
# 26011   Y   24
# 26013   Y   2
# 26013   Y   24
# 26018   Y   4
# 26018   Y   48
# 26039   Y   3
# 26039   Y   36
# 26049   Y   3
# 26049   Y   36
# 26094   Y   4
# 26094   Y   48
# 26095   Y   2
# 26095   Y   24
# 26106   Y   2
# 26106   Y   24
# 26113   Y   4
# 26113   Y   48
# 26126   Y   4
# 26126   Y   48
# 26138   Y   5
# 26138   Y   60
# 26142   Y   3
# 26142   Y   36
# 26155   Y   3
# 26155   Y   36
# 26227   Y   4
# 26227   Y   48
# 26318   Y   3
# 26318   Y   36
# 26374   Y   3
# 26374   Y   36
# 26394   Y   1
# 26394   Y   12
# 26399   Y   1
# 26399   Y   12
# 26415   Y   2
# 26415   Y   24
# 26448   Y   4
# 26448   Y   48
# 26465   Y   3
# 26465   Y   36
# 26488   Y   3
# 26488   Y   36
# 26553   Y   5
# 26553   Y   60
# 26554   Y   3
# 26554   Y   36
# 26564   Y   4
# 26564   Y   48
# 26565   Y   2
# 26565   Y   24
# 26568   Y   1
# 26568   Y   12
# 26582   Y   3
# 26582   Y   36
# 26604   Y   5
# 26604   Y   60
# 26606   Y   2
# 26606   Y   24
# 26609   Y   5
# 26609   Y   60
# 26610   Y   3
# 26610   Y   36
# 26626   Y   4
# 26626   Y   48
# 26628   Y   3
# 26628   Y   36
# 26648   Y   4
# 26648   Y   48
# 26665   Y   3
# 26665   Y   36
# 26706   Y   3
# 26706   Y   36
# 26714   Y   4
# 26714   Y   48
# 26715   Y   2
# 26715   Y   24
# 26731   Y   3
# 26731   Y   36
# 26756   Y   3
# 26756   Y   36
# 26765   Y   2
# 26765   Y   24
# 26778   Y   4
# 26778   Y   48
# 26789   Y   2
# 26789   Y   24
# 26820   Y   2
# 26820   Y   24
# 26884   Y   1
# 26884   Y   12
# 26910   Y   3
# 26910   Y   36
# 26926   Y   3
# 26926   Y   36
# 26980   Y   4
# 26980   Y   48
# 27048   Y   5
# 27048   Y   60
# 27051   Y   2
# 27051   Y   24
# 27061   Y   3
# 27061   Y   36
# 27075   Y   2
# 27075   Y   24
# 27094   Y   5
# 27094   Y   60
# 27126   Y   5
# 27126   Y   60
# 27138   Y   4
# 27138   Y   48
# 27155   Y   4
# 27155   Y   48
# 27180   Y   4
# 27180   Y   48
# 27191   Y   3
# 27191   Y   36
# 27192   Y   3
# 27192   Y   36
# 27195   Y   5
# 27195   Y   60
# 27196   Y   4
# 27196   Y   48
# 27241   Y   4
# 27241   Y   48
# 27245   Y   4
# 27245   Y   48
# 27285   Y   3
# 27285   Y   36
# 27308   Y   4
# 27308   Y   48
# 27309   Y   3
# 27309   Y   36
# 27327   Y   2
# 27327   Y   24
# 27350   Y   3
# 27350   Y   36
# 27366   Y   4
# 27366   Y   48
# 27379   Y   2
# 27379   Y   24
# 27388   Y   4
# 27388   Y   48
# 27394   Y   4
# 27394   Y   48
# 27409   Y   4
# 27409   Y   48
# 27469   Y   4
# 27469   Y   48
# 27498   Y   3
# 27498   Y   36
# 27534   Y   4
# 27534   Y   48
# 27535   Y   2
# 27535   Y   24
# 27562   Y   3
# 27562   Y   36
# 27620   Y   3
# 27620   Y   36
# 27631   Y   3
# 27631   Y   36
# 27659   Y   2
# 27659   Y   24
# 27719   Y   4
# 27719   Y   48
# 27734   Y   2
# 27734   Y   24
# 27738   Y   3
# 27738   Y   36
# 27788   Y   4
# 27788   Y   48
# 27793   Y   4
# 27793   Y   48
# 27824   Y   5
# 27824   Y   60
# 27837   Y   4
# 27837   Y   48
# 27853   Y   3
# 27853   Y   36
# 27906   Y   4
# 27906   Y   48
# 27943   Y   4
# 27943   Y   48
# 27961   Y   3
# 27961   Y   36
# 27969   Y   4
# 27969   Y   48
# 28017   Y   4
# 28017   Y   48
# 28062   Y   4
# 28062   Y   48
# 28121   Y   3
# 28121   Y   36
# 28151   Y   5
# 28151   Y   60
# 28168   Y   4
# 28168   Y   48
# 28180   Y   5
# 28180   Y   60
# 28193   Y   2
# 28193   Y   24
# 28215   Y   3
# 28215   Y   36
# 28235   Y   3
# 28235   Y   36
# 28287   Y   4
# 28287   Y   48
# 28297   Y   3
# 28297   Y   36
# 28307   Y   4
# 28307   Y   48
# 28314   Y   2
# 28314   Y   24
# 28334   Y   2
# 28334   Y   24
# 28443   Y   3
# 28443   Y   36
# 28453   Y   4
# 28453   Y   48
# 28454   Y   3
# 28454   Y   36
# 28479   Y   4
# 28479   Y   48
# 28486   Y   4
# 28486   Y   48
# 28489   Y   4
# 28489   Y   48
# 28527   Y   3
# 28527   Y   36
# 28535   Y   4
# 28535   Y   48
# 28539   Y   4
# 28539   Y   48
# 28544   Y   4
# 28544   Y   48
# 28548   Y   3
# 28548   Y   36
# 28566   Y   3
# 28566   Y   36
# 28597   Y   4
# 28597   Y   48
# 28598   Y   2
# 28598   Y   24
# 28610   Y   3
# 28610   Y   36
# 28611   Y   2
# 28611   Y   24
# 28663   Y   4
# 28663   Y   48
# 28675   Y   3
# 28675   Y   36
# 28701   Y   3
# 28701   Y   36
# 28712   Y   2
# 28712   Y   24
# 28727   Y   1
# 28727   Y   12
# 28794   Y   4
# 28794   Y   48
# 28822   Y   2
# 28822   Y   24
# 28835   Y   4
# 28835   Y   48
# 28852   Y   4
# 28852   Y   48
# 28881   Y   3
# 28881   Y   36
# 28904   Y   1
# 28904   Y   12
# 28974   Y   5
# 28974   Y   60
# 29008   Y   5
# 29008   Y   60
# 29009   Y   3
# 29009   Y   36
# 29043   Y   3
# 29043   Y   36
# 29049   Y   4
# 29049   Y   48
# 29070   Y   3
# 29070   Y   36
# 29128   Y   4
# 29128   Y   48
# 29132   Y   4
# 29132   Y   48
# 29196   Y   3
# 29196   Y   36
# 29238   Y   4
# 29238   Y   48
# 29239   Y   3
# 29239   Y   36
# 29265   Y   3
# 29265   Y   36
# 29294   Y   4
# 29294   Y   48
# 29304   Y   2
# 29304   Y   24
# 29343   Y   3
# 29343   Y   36
# 29348   Y   4
# 29348   Y   48
# 29352   Y   3
# 29352   Y   36
# 29396   Y   4
# 29396   Y   48
# 29414   Y   3
# 29414   Y   36
# 29422   Y   5
# 29422   Y   60
# 29423   Y   3
# 29423   Y   36
# 29426   Y   3
# 29426   Y   36
# 29444   Y   2
# 29444   Y   24
# 29469   Y   2
# 29469   Y   24
# 29499   Y   2
# 29499   Y   24
# 29521   Y   4
# 29521   Y   48
# 29527   Y   5
# 29527   Y   60
# 29528   Y   3
# 29528   Y   36
# 29619   Y   4
# 29619   Y   48
# 29626   Y   4
# 29626   Y   48
# 29629   Y   4
# 29629   Y   48
# 29654   Y   3
# 29654   Y   36
# 29706   Y   5
# 29706   Y   60
# 29709   Y   5
# 29709   Y   60
# 29736   Y   3
# 29736   Y   36
# 29757   Y   4
# 29757   Y   48
# 29976   Y   3
# 29976   Y   36
# 29981   Y   4
# 29981   Y   48
# 29982   Y   2
# 29982   Y   24
# 30025   Y   3
# 30025   Y   36
# 30028   Y   4
# 30028   Y   48
# 30055   Y   1
# 30055   Y   12
# 30063   Y   3
# 30063   Y   36
# 30100   Y   5
# 30100   Y   60
# 30120   Y   3
# 30120   Y   36
# 30123   Y   5
# 30123   Y   60
# 30167   Y   4
# 30167   Y   48
# 30173   Y   3
# 30173   Y   36
# 30217   Y   4
# 30217   Y   48
# 30219   Y   3
# 30219   Y   36
# 30240   Y   4
# 30240   Y   48
# 30245   Y   4
# 30245   Y   48
# 30268   Y   5
# 30268   Y   60
# 30277   Y   4
# 30277   Y   48
# 30297   Y   2
# 30297   Y   24
# 30306   Y   2
# 30306   Y   24
# 30333   Y   5
# 30333   Y   60
# 30334   Y   3
# 30334   Y   36
# 30346   Y   4
# 30346   Y   48
# 30372   Y   5
# 30372   Y   60
# 30373   Y   3
# 30373   Y   36
# 30395   Y   4
# 30395   Y   48
# 30404   Y   5
# 30404   Y   60
# 30407   Y   2
# 30407   Y   24
# 30502   Y   3
# 30502   Y   36
# 30517   Y   3
# 30517   Y   36
# 30520   Y   4
# 30520   Y   48
# 30534   Y   2
# 30534   Y   24
# 30535   Y   1
# 30535   Y   12
# 30583   Y   3
# 30583   Y   36
# 30589   Y   3
# 30589   Y   36
# 30669   Y   5
# 30669   Y   60
# 30670   Y   3
# 30670   Y   36
# 30704   Y   2
# 30704   Y   24
# 30720   Y   4
# 30720   Y   48
# 30725   Y   3
# 30725   Y   36
# 30741   Y   3
# 30741   Y   36
# 30770   Y   4
# 30770   Y   48
# 30771   Y   2
# 30771   Y   24
# 30783   Y   2
# 30783   Y   24
# 30789   Y   4
# 30789   Y   48
# 30831   Y   4
# 30831   Y   48
# 30832   Y   2
# 30832   Y   24
# 30836   Y   3
# 30836   Y   36
# 30896   Y   4
# 30896   Y   48
# 30900   Y   3
# 30900   Y   36
# 30903   Y   3
# 30903   Y   36
# 30906   Y   1
# 30906   Y   12
# 30960   Y   4
# 30960   Y   48
# 30976   Y   4
# 30976   Y   48
# 30977   Y   3
# 30977   Y   36
# 30982   Y   4
# 30982   Y   48
# 30984   Y   5
# 30984   Y   60
# 30985   Y   4
# 30985   Y   48
# 30989   Y   5
# 30989   Y   60
# 30998   Y   5
# 30998   Y   60
# 31043   Y   4
# 31043   Y   48
# 31048   Y   5
# 31048   Y   60
# 31052   Y   3
# 31052   Y   36
# 31070   Y   3
# 31070   Y   36
# 31084   Y   1
# 31084   Y   12
# 31093   Y   4
# 31093   Y   48
# 31111   Y   5
# 31111   Y   60
# 31133   Y   5
# 31133   Y   60
# 31228   Y   3
# 31228   Y   36
# 31237   Y   3
# 31237   Y   36
# 31244   Y   4
# 31244   Y   48
# 31256   Y   3
# 31256   Y   36
# 31262   Y   3
# 31262   Y   36
# 31284   Y   3
# 31284   Y   36
# 31298   Y   5
# 31298   Y   60
# 31301   Y   4
# 31301   Y   48
# 31323   Y   4
# 31323   Y   48
# 31370   Y   5
# 31370   Y   60
# 31371   Y   4
# 31371   Y   48
# 31403   Y   3
# 31403   Y   36
# 31435   Y   3
# 31435   Y   36
# 31441   Y   2
# 31441   Y   24
# 31447   Y

# %%
for i in data[data['age_code'] == 'D'].index:
    x = data['age'][i]
    print(i,' ',data['age_code'][i],' ',data['age'][i])
    if data['age'][i] < 15:
        data['age'][i] = 0
    else :
        data['age'][i] = 1
    print(i,' ',data['age_code'][i],' ',data['age'][i])

# %%
data.columns.values

# %%
data = data.drop(['age_code', 'day_or_month_for_breast_feeding_','treatment_type'] , axis=1)

# %%
data.columns.values

# %%
data.shape

# %%
for i in data.columns:
    print(i)
    print(data[i][data[i] == -1].value_counts())
# Out:
# state_code
# Series([], Name: state_code, dtype: int64)
# record_code_iodine
# Series([], Name: record_code_iodine, dtype: int64)
# sex
# Series([], Name: sex, dtype: int64)
# age
# Series([], Name: age, dtype: int64)
# weight_in_kg
# Series([], Name: weight_in_kg, dtype: int64)
# length_height_cm
# Series([], Name: length_height_cm, dtype: int64)
# haemoglobin_level
# Series([], Name: haemoglobin_level, dtype: int64)
# first_breast_feeding
# Series([], Name: first_breast_feeding, dtype: int64)
# is_cur_breast_feeding
# Series([], Name: is_cur_breast_feeding, dtype: int64)
# day_or_month_for_breast_feeding
# Series([], Name: day_or_month_for_breast_feeding, dtype: int64)
# water_month
# Series([], Name: water_month, dtype: int64)
# ani_milk_month
# Series([], Name: ani_milk_month, dtype: int64)
# semisolid_month_or_day
# Series([], Name: semisolid_month_or_day, dtype: int64)
# solid_month
# Series([], Name: solid_month, dtype: int64)
# vegetables_month_or_day
# Series([], Name: vegetables_month_or_day, dtype: int64)
# illness_type
# Series([], Name: illness_type, dtype: int64)
# treatment_type
# -1    11091
# Name: treatment_type, dtype: int64

# %%
#data.to_csv('cleaned data/MP.csv', encoding='utf-8', index=False)
